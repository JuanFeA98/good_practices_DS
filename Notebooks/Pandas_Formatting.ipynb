# %% [markdown]
# # **Pandas**

# %% [markdown]
# ### **Librerías**

# %%
import pandas as pd
import numpy as np

# %%
import dataframe_image as dfi

# %% [markdown]
# ### **Datos**

# %%
# Data para el producto A

df_a = pd.DataFrame({
    'Month':pd.date_range(
        start = '01-01-2012',
        end = '31-12-2022',
        freq = 'MS'
    ),
    'Quotes':np.random.randint(
        low = 1_000_000,
        high = 2_500_000,
        size = 132
    ),
    'Numbers':np.random.randint(
        low = 300_000,
        high = 500_000,
        size = 132
    ),
    'Amounts':np.random.randint(
        low = 750_000,
        high = 1_250_000,
        size = 132
    )
})

df_a['Product'] = 'A'

# Data para el producto B

df_b = pd.DataFrame({
    'Month':pd.date_range(
        start = '01-01-2012',
        end = '31-12-2022',
        freq = 'MS'
    ),
    'Quotes':np.random.randint(
        low = 100_000,
        high = 800_000,
        size = 132
    ),
    'Numbers':np.random.randint(
        low = 10_000,
        high = 95_000,
        size = 132
    ),
    'Amounts':np.random.randint(
        low = 450_000,
        high = 750_000,
        size = 132
    )
})

df_b['Product'] = 'B'

# %%
# Combinamos los datos
df = pd.concat([df_a, df_b], axis=0)
df.sort_values(by='Month', inplace=True)
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#        Month   Quotes  Numbers  Amounts Product
# 0 2012-01-01  1297877   427302   893590       A
# 1 2012-01-01   557071    44383   648487       B
# 2 2012-02-01  2493819   358599  1089789       A
# 3 2012-02-01   150071    31385   738013       B
# 4 2012-03-01  1307998   359458   807437       A

# %%
# Columnas calculadas 
df['Average_Sale'] = df['Amounts'] / df['Numbers']
df['Product_Conversion'] = df['Numbers'] / df['Quotes']

# %%
df.head()
# Out:
#        Month   Quotes  Numbers  Amounts Product  Average_Sale  \
# 0 2012-01-01  1297877   427302   893590       A      2.091238
# 1 2012-01-01   557071    44383   648487       B     14.611157
# 2 2012-02-01  2493819   358599  1089789       A      3.039019
# 3 2012-02-01   150071    31385   738013       B     23.514832
# 4 2012-03-01  1307998   359458   807437       A      2.246262
#
#    Product_Conversion
# 0            0.329232
# 1            0.079672
# 2            0.143795
# 3            0.209134
# 4            0.274815

# %% [markdown]
# ### **1. Ajuste del formato**

# %%
# Ajustamos los formatos de los números
df.head().style.format({
    # Ajustamos el formato de fecha
    # 'Month': '{:%Y-%m}',
    # 'Month': '{:%B-%Y}',
    'Month': '{:%b-%Y}',

    # Ajustamos el formato de los números
    'Quotes': '{:,.0f}',
    'Numbers': '{:,.0f}',
    'Amounts': '${:,.0f}',
    # 'Average_Sale': '{:,.2f} ($)',
    'Average_Sale': '${:,.2f}',
    'Product_Conversion': '{:.2%}',
})
# .hide()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e0afc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0afc_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_e0afc_level0_col1" class="col_heading level0 col1" >Quotes</th>
#       <th id="T_e0afc_level0_col2" class="col_heading level0 col2" >Numbers</th>
#       <th id="T_e0afc_level0_col3" class="col_heading level0 col3" >Amounts</th>
#       <th id="T_e0afc_level0_col4" class="col_heading level0 col4" >Product</th>
#       <th id="T_e0afc_level0_col5" class="col_heading level0 col5" >Average_Sale</th>
#       <th id="T_e0afc_level0_col6" class="col_heading level0 col6" >Product_Conversion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0afc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0afc_row0_col0" class="data row0 col0" >Jan-2012</td>
#       <td id="T_e0afc_row0_col1" class="data row0 col1" >1,297,877</td>
#       <td id="T_e0afc_row0_col2" class="data row0 col2" >427,302</td>
#       <td id="T_e0afc_row0_col3" class="data row0 col3" >$893,590</td>
#       <td id="T_e0afc_row0_col4" class="data row0 col4" >A</td>
#       <td id="T_e0afc_row0_col5" class="data row0 col5" >$2.09</td>
#       <td id="T_e0afc_row0_col6" class="data row0 col6" >32.92%</td>
#     </tr>
#     <tr>
#       <th id="T_e0afc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0afc_row1_col0" class="data row1 col0" >Jan-2012</td>
#       <td id="T_e0afc_row1_col1" class="data row1 col1" >557,071</td>
#       <td id="T_e0afc_row1_col2" class="data row1 col2" >44,383</td>
#       <td id="T_e0afc_row1_col3" class="data row1 col3" >$648,487</td>
#       <td id="T_e0afc_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_e0afc_row1_col5" class="data row1 col5" >$14.61</td>
#       <td id="T_e0afc_row1_col6" class="data row1 col6" >7.97%</td>
#     </tr>
#     <tr>
#       <th id="T_e0afc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0afc_row2_col0" class="data row2 col0" >Feb-2012</td>
#       <td id="T_e0afc_row2_col1" class="data row2 col1" >2,493,819</td>
#       <td id="T_e0afc_row2_col2" class="data row2 col2" >358,599</td>
#       <td id="T_e0afc_row2_col3" class="data row2 col3" >$1,089,789</td>
#       <td id="T_e0afc_row2_col4" class="data row2 col4" >A</td>
#       <td id="T_e0afc_row2_col5" class="data row2 col5" >$3.04</td>
#       <td id="T_e0afc_row2_col6" class="data row2 col6" >14.38%</td>
#     </tr>
#     <tr>
#       <th id="T_e0afc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0afc_row3_col0" class="data row3 col0" >Feb-2012</td>
#       <td id="T_e0afc_row3_col1" class="data row3 col1" >150,071</td>
#       <td id="T_e0afc_row3_col2" class="data row3 col2" >31,385</td>
#       <td id="T_e0afc_row3_col3" class="data row3 col3" >$738,013</td>
#       <td id="T_e0afc_row3_col4" class="data row3 col4" >B</td>
#       <td id="T_e0afc_row3_col5" class="data row3 col5" >$23.51</td>
#       <td id="T_e0afc_row3_col6" class="data row3 col6" >20.91%</td>
#     </tr>
#     <tr>
#       <th id="T_e0afc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0afc_row4_col0" class="data row4 col0" >Mar-2012</td>
#       <td id="T_e0afc_row4_col1" class="data row4 col1" >1,307,998</td>
#       <td id="T_e0afc_row4_col2" class="data row4 col2" >359,458</td>
#       <td id="T_e0afc_row4_col3" class="data row4 col3" >$807,437</td>
#       <td id="T_e0afc_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_e0afc_row4_col5" class="data row4 col5" >$2.25</td>
#       <td id="T_e0afc_row4_col6" class="data row4 col6" >27.48%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### **2. Ajuste del formato condicional**

# %% [markdown]
# ##### **Resaltar por una categoría**

# %%
def highlight_product(row_data, product, color='yellow'):
    """
    Resalta las filas del DataFrame basándose en el valor de la columna 'Product'.

    Args:
        row_data (pd.Series): Una fila del DataFrame.
        product (any): La columna con la cual se resaltarán las filas.
        color (str, optional): El color para resaltar las filas. Por defecto, 'yellow'.

    Returns:
        List[str]: Lista de strings con estilo CSS para resaltar la fila.
    """
    
    # Crea una nueva Serie de pandas llamada 'row' con valores booleanos inicializados en False
    row = pd.Series(data=False, index=row_data.index)

    # Establece el valor en True para la columna 'Product' si el valor en esa fila es igual al producto proporcionado
    row['Product'] = row_data.loc['Product'] == product

    # Retorna una lista de strings con el formato 'background-color: {color}' si al menos un valor en 'row' es True
    return [f'background-color: {color}' if row.any() else '' for value in row]

# %%
# Aplicamos la condición sobre las categorías
df.head().style.apply(
    highlight_product, product='A', color='#18314f', axis=1
).format({
    # Ajustamos el formato de fecha
    'Month': '{:%b-%Y}',

    # Ajustamos el formato de los números
    'Quotes': '{:,.0f}',
    'Numbers': '{:,.0f}',
    'Amounts': '${:,.0f}',
    'Average_Sale': '${:,.2f}',
    'Product_Conversion': '{:.2%}',
}).hide()
# Out:
# <style type="text/css">
# #T_a7cb9_row0_col0, #T_a7cb9_row0_col1, #T_a7cb9_row0_col2, #T_a7cb9_row0_col3, #T_a7cb9_row0_col4, #T_a7cb9_row0_col5, #T_a7cb9_row0_col6, #T_a7cb9_row2_col0, #T_a7cb9_row2_col1, #T_a7cb9_row2_col2, #T_a7cb9_row2_col3, #T_a7cb9_row2_col4, #T_a7cb9_row2_col5, #T_a7cb9_row2_col6, #T_a7cb9_row4_col0, #T_a7cb9_row4_col1, #T_a7cb9_row4_col2, #T_a7cb9_row4_col3, #T_a7cb9_row4_col4, #T_a7cb9_row4_col5, #T_a7cb9_row4_col6 {
#   background-color: #18314f;
# }
# </style>
# <table id="T_a7cb9">
#   <thead>
#     <tr>
#       <th id="T_a7cb9_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_a7cb9_level0_col1" class="col_heading level0 col1" >Quotes</th>
#       <th id="T_a7cb9_level0_col2" class="col_heading level0 col2" >Numbers</th>
#       <th id="T_a7cb9_level0_col3" class="col_heading level0 col3" >Amounts</th>
#       <th id="T_a7cb9_level0_col4" class="col_heading level0 col4" >Product</th>
#       <th id="T_a7cb9_level0_col5" class="col_heading level0 col5" >Average_Sale</th>
#       <th id="T_a7cb9_level0_col6" class="col_heading level0 col6" >Product_Conversion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a7cb9_row0_col0" class="data row0 col0" >Jan-2012</td>
#       <td id="T_a7cb9_row0_col1" class="data row0 col1" >1,297,877</td>
#       <td id="T_a7cb9_row0_col2" class="data row0 col2" >427,302</td>
#       <td id="T_a7cb9_row0_col3" class="data row0 col3" >$893,590</td>
#       <td id="T_a7cb9_row0_col4" class="data row0 col4" >A</td>
#       <td id="T_a7cb9_row0_col5" class="data row0 col5" >$2.09</td>
#       <td id="T_a7cb9_row0_col6" class="data row0 col6" >32.92%</td>
#     </tr>
#     <tr>
#       <td id="T_a7cb9_row1_col0" class="data row1 col0" >Jan-2012</td>
#       <td id="T_a7cb9_row1_col1" class="data row1 col1" >557,071</td>
#       <td id="T_a7cb9_row1_col2" class="data row1 col2" >44,383</td>
#       <td id="T_a7cb9_row1_col3" class="data row1 col3" >$648,487</td>
#       <td id="T_a7cb9_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_a7cb9_row1_col5" class="data row1 col5" >$14.61</td>
#       <td id="T_a7cb9_row1_col6" class="data row1 col6" >7.97%</td>
#     </tr>
#     <tr>
#       <td id="T_a7cb9_row2_col0" class="data row2 col0" >Feb-2012</td>
#       <td id="T_a7cb9_row2_col1" class="data row2 col1" >2,493,819</td>
#       <td id="T_a7cb9_row2_col2" class="data row2 col2" >358,599</td>
#       <td id="T_a7cb9_row2_col3" class="data row2 col3" >$1,089,789</td>
#       <td id="T_a7cb9_row2_col4" class="data row2 col4" >A</td>
#       <td id="T_a7cb9_row2_col5" class="data row2 col5" >$3.04</td>
#       <td id="T_a7cb9_row2_col6" class="data row2 col6" >14.38%</td>
#     </tr>
#     <tr>
#       <td id="T_a7cb9_row3_col0" class="data row3 col0" >Feb-2012</td>
#       <td id="T_a7cb9_row3_col1" class="data row3 col1" >150,071</td>
#       <td id="T_a7cb9_row3_col2" class="data row3 col2" >31,385</td>
#       <td id="T_a7cb9_row3_col3" class="data row3 col3" >$738,013</td>
#       <td id="T_a7cb9_row3_col4" class="data row3 col4" >B</td>
#       <td id="T_a7cb9_row3_col5" class="data row3 col5" >$23.51</td>
#       <td id="T_a7cb9_row3_col6" class="data row3 col6" >20.91%</td>
#     </tr>
#     <tr>
#       <td id="T_a7cb9_row4_col0" class="data row4 col0" >Mar-2012</td>
#       <td id="T_a7cb9_row4_col1" class="data row4 col1" >1,307,998</td>
#       <td id="T_a7cb9_row4_col2" class="data row4 col2" >359,458</td>
#       <td id="T_a7cb9_row4_col3" class="data row4 col3" >$807,437</td>
#       <td id="T_a7cb9_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_a7cb9_row4_col5" class="data row4 col5" >$2.25</td>
#       <td id="T_a7cb9_row4_col6" class="data row4 col6" >27.48%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### **Resaltar por valores numéricos**

# %%
def highlight_average_sale(row_data, sale_threshold, color='yellow'):
    """
    Resalta las filas del DataFrame basándose en el valor de la columna 'Average_Sale'.

    Args:
        row_data (pd.Series): Una fila del DataFrame.
        sale_threshold (any): Umbral por el cual se resaltaran las filas.
        color (str, optional): El color para resaltar las filas. Por defecto, 'yellow'.

    Returns:
        List[str]: Lista de strings con estilo CSS para resaltar la fila.
    """
    
    # Crea una nueva Serie de pandas llamada 'row' con valores booleanos inicializados en False
    row = pd.Series(data=False, index=row_data.index)

    # Establece el valor en True para la columna 'Product' si el valor en esa fila es igual al producto proporcionado
    row['Product'] = row_data.loc['Average_Sale'] < sale_threshold

    # Retorna una lista de strings con el formato 'background-color: {color}' si al menos un valor en 'row' es True
    return [f'background-color: {color}' if row.any() else '' for value in row]

# %%
# Aplicamos la condición sobre las categorías
df.head().style.apply(
    highlight_product, product='A', color='#18314f', axis=1
).format({
    # Ajustamos el formato de fecha
    'Month': '{:%b-%Y}',

    # Ajustamos el formato de los números
    'Quotes': '{:,.0f}',
    'Numbers': '{:,.0f}',
    'Amounts': '${:,.0f}',
    'Average_Sale': '${:,.2f}',
    'Product_Conversion': '{:.2%}',
}).hide()
# Out:
# <style type="text/css">
# #T_51544_row0_col0, #T_51544_row0_col1, #T_51544_row0_col2, #T_51544_row0_col3, #T_51544_row0_col4, #T_51544_row0_col5, #T_51544_row0_col6, #T_51544_row2_col0, #T_51544_row2_col1, #T_51544_row2_col2, #T_51544_row2_col3, #T_51544_row2_col4, #T_51544_row2_col5, #T_51544_row2_col6, #T_51544_row4_col0, #T_51544_row4_col1, #T_51544_row4_col2, #T_51544_row4_col3, #T_51544_row4_col4, #T_51544_row4_col5, #T_51544_row4_col6 {
#   background-color: #18314f;
# }
# </style>
# <table id="T_51544">
#   <thead>
#     <tr>
#       <th id="T_51544_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_51544_level0_col1" class="col_heading level0 col1" >Quotes</th>
#       <th id="T_51544_level0_col2" class="col_heading level0 col2" >Numbers</th>
#       <th id="T_51544_level0_col3" class="col_heading level0 col3" >Amounts</th>
#       <th id="T_51544_level0_col4" class="col_heading level0 col4" >Product</th>
#       <th id="T_51544_level0_col5" class="col_heading level0 col5" >Average_Sale</th>
#       <th id="T_51544_level0_col6" class="col_heading level0 col6" >Product_Conversion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_51544_row0_col0" class="data row0 col0" >Jan-2012</td>
#       <td id="T_51544_row0_col1" class="data row0 col1" >1,297,877</td>
#       <td id="T_51544_row0_col2" class="data row0 col2" >427,302</td>
#       <td id="T_51544_row0_col3" class="data row0 col3" >$893,590</td>
#       <td id="T_51544_row0_col4" class="data row0 col4" >A</td>
#       <td id="T_51544_row0_col5" class="data row0 col5" >$2.09</td>
#       <td id="T_51544_row0_col6" class="data row0 col6" >32.92%</td>
#     </tr>
#     <tr>
#       <td id="T_51544_row1_col0" class="data row1 col0" >Jan-2012</td>
#       <td id="T_51544_row1_col1" class="data row1 col1" >557,071</td>
#       <td id="T_51544_row1_col2" class="data row1 col2" >44,383</td>
#       <td id="T_51544_row1_col3" class="data row1 col3" >$648,487</td>
#       <td id="T_51544_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_51544_row1_col5" class="data row1 col5" >$14.61</td>
#       <td id="T_51544_row1_col6" class="data row1 col6" >7.97%</td>
#     </tr>
#     <tr>
#       <td id="T_51544_row2_col0" class="data row2 col0" >Feb-2012</td>
#       <td id="T_51544_row2_col1" class="data row2 col1" >2,493,819</td>
#       <td id="T_51544_row2_col2" class="data row2 col2" >358,599</td>
#       <td id="T_51544_row2_col3" class="data row2 col3" >$1,089,789</td>
#       <td id="T_51544_row2_col4" class="data row2 col4" >A</td>
#       <td id="T_51544_row2_col5" class="data row2 col5" >$3.04</td>
#       <td id="T_51544_row2_col6" class="data row2 col6" >14.38%</td>
#     </tr>
#     <tr>
#       <td id="T_51544_row3_col0" class="data row3 col0" >Feb-2012</td>
#       <td id="T_51544_row3_col1" class="data row3 col1" >150,071</td>
#       <td id="T_51544_row3_col2" class="data row3 col2" >31,385</td>
#       <td id="T_51544_row3_col3" class="data row3 col3" >$738,013</td>
#       <td id="T_51544_row3_col4" class="data row3 col4" >B</td>
#       <td id="T_51544_row3_col5" class="data row3 col5" >$23.51</td>
#       <td id="T_51544_row3_col6" class="data row3 col6" >20.91%</td>
#     </tr>
#     <tr>
#       <td id="T_51544_row4_col0" class="data row4 col0" >Mar-2012</td>
#       <td id="T_51544_row4_col1" class="data row4 col1" >1,307,998</td>
#       <td id="T_51544_row4_col2" class="data row4 col2" >359,458</td>
#       <td id="T_51544_row4_col3" class="data row4 col3" >$807,437</td>
#       <td id="T_51544_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_51544_row4_col5" class="data row4 col5" >$2.25</td>
#       <td id="T_51544_row4_col6" class="data row4 col6" >27.48%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### **Cambiar el color del texto por valores numéricos**

# %%
def colour_threshold(row_data, threshold=0.5):
    """
    Aplica un esquema de color a una fila del DataFrame basándose en un umbral.

    Args:
        row_data (pd.Series): Una fila del DataFrame.
        threshold (float, optional): El umbral para aplicar el esquema de color. 
                                        Por defecto, el umbral es 0.5.

    Returns:
        List[str]: Lista de strings con estilo CSS para el color de texto. 
                    Si el valor en la fila es menor que el umbral, el estilo será 'color: red', 
                    de lo contrario, el estilo será 'color: green'.

    """    

    # Crea una nueva Serie de pandas llamada 'row' con valores booleanos inicializados en False
    row = pd.Series(data=False, index=row_data.index)

    # Retorna una lista de strings con el formato 'color: red' si el valor en la fila es menor que el umbral,
    # de lo contrario, retorna 'color: green'
    return [f'color: red' if row_data.iloc[0] < threshold else 'color: green' for value in row]

# %%
# Aplicamos la condición sobre las categorías
df.head().style.apply(
    highlight_product, product='A', color='#18314f', axis=1
).apply(
    colour_threshold, subset=['Product_Conversion'], threshold= 0.2, axis=1
).format({
    # Ajustamos el formato de fecha
    'Month': '{:%b-%Y}',

    # Ajustamos el formato de los números
    'Quotes': '{:,.0f}',
    'Numbers': '{:,.0f}',
    'Amounts': '${:,.0f}',
    'Average_Sale': '${:,.2f}',
    'Product_Conversion': '{:.2%}',
}).hide()
# Out:
# <style type="text/css">
# #T_45299_row0_col0, #T_45299_row0_col1, #T_45299_row0_col2, #T_45299_row0_col3, #T_45299_row0_col4, #T_45299_row0_col5, #T_45299_row2_col0, #T_45299_row2_col1, #T_45299_row2_col2, #T_45299_row2_col3, #T_45299_row2_col4, #T_45299_row2_col5, #T_45299_row4_col0, #T_45299_row4_col1, #T_45299_row4_col2, #T_45299_row4_col3, #T_45299_row4_col4, #T_45299_row4_col5 {
#   background-color: #18314f;
# }
# #T_45299_row0_col6, #T_45299_row4_col6 {
#   background-color: #18314f;
#   color: green;
# }
# #T_45299_row1_col6 {
#   color: red;
# }
# #T_45299_row2_col6 {
#   background-color: #18314f;
#   color: red;
# }
# #T_45299_row3_col6 {
#   color: green;
# }
# </style>
# <table id="T_45299">
#   <thead>
#     <tr>
#       <th id="T_45299_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_45299_level0_col1" class="col_heading level0 col1" >Quotes</th>
#       <th id="T_45299_level0_col2" class="col_heading level0 col2" >Numbers</th>
#       <th id="T_45299_level0_col3" class="col_heading level0 col3" >Amounts</th>
#       <th id="T_45299_level0_col4" class="col_heading level0 col4" >Product</th>
#       <th id="T_45299_level0_col5" class="col_heading level0 col5" >Average_Sale</th>
#       <th id="T_45299_level0_col6" class="col_heading level0 col6" >Product_Conversion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_45299_row0_col0" class="data row0 col0" >Jan-2012</td>
#       <td id="T_45299_row0_col1" class="data row0 col1" >1,297,877</td>
#       <td id="T_45299_row0_col2" class="data row0 col2" >427,302</td>
#       <td id="T_45299_row0_col3" class="data row0 col3" >$893,590</td>
#       <td id="T_45299_row0_col4" class="data row0 col4" >A</td>
#       <td id="T_45299_row0_col5" class="data row0 col5" >$2.09</td>
#       <td id="T_45299_row0_col6" class="data row0 col6" >32.92%</td>
#     </tr>
#     <tr>
#       <td id="T_45299_row1_col0" class="data row1 col0" >Jan-2012</td>
#       <td id="T_45299_row1_col1" class="data row1 col1" >557,071</td>
#       <td id="T_45299_row1_col2" class="data row1 col2" >44,383</td>
#       <td id="T_45299_row1_col3" class="data row1 col3" >$648,487</td>
#       <td id="T_45299_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_45299_row1_col5" class="data row1 col5" >$14.61</td>
#       <td id="T_45299_row1_col6" class="data row1 col6" >7.97%</td>
#     </tr>
#     <tr>
#       <td id="T_45299_row2_col0" class="data row2 col0" >Feb-2012</td>
#       <td id="T_45299_row2_col1" class="data row2 col1" >2,493,819</td>
#       <td id="T_45299_row2_col2" class="data row2 col2" >358,599</td>
#       <td id="T_45299_row2_col3" class="data row2 col3" >$1,089,789</td>
#       <td id="T_45299_row2_col4" class="data row2 col4" >A</td>
#       <td id="T_45299_row2_col5" class="data row2 col5" >$3.04</td>
#       <td id="T_45299_row2_col6" class="data row2 col6" >14.38%</td>
#     </tr>
#     <tr>
#       <td id="T_45299_row3_col0" class="data row3 col0" >Feb-2012</td>
#       <td id="T_45299_row3_col1" class="data row3 col1" >150,071</td>
#       <td id="T_45299_row3_col2" class="data row3 col2" >31,385</td>
#       <td id="T_45299_row3_col3" class="data row3 col3" >$738,013</td>
#       <td id="T_45299_row3_col4" class="data row3 col4" >B</td>
#       <td id="T_45299_row3_col5" class="data row3 col5" >$23.51</td>
#       <td id="T_45299_row3_col6" class="data row3 col6" >20.91%</td>
#     </tr>
#     <tr>
#       <td id="T_45299_row4_col0" class="data row4 col0" >Mar-2012</td>
#       <td id="T_45299_row4_col1" class="data row4 col1" >1,307,998</td>
#       <td id="T_45299_row4_col2" class="data row4 col2" >359,458</td>
#       <td id="T_45299_row4_col3" class="data row4 col3" >$807,437</td>
#       <td id="T_45299_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_45299_row4_col5" class="data row4 col5" >$2.25</td>
#       <td id="T_45299_row4_col6" class="data row4 col6" >27.48%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### **Ajuste de otros formatos**

# %%
# Aplicamos la condición sobre las categorías
df.head().style.set_properties(**{'text-align':'center'}).apply(
    highlight_product, product='A', color='#18314f', axis=1
).apply(
    colour_threshold, subset=['Product_Conversion'], threshold= 0.2, axis=1
).format({
    # Ajustamos el formato de fecha
    'Month': '{:%b-%Y}',

    # Ajustamos el formato de los números
    'Quotes': '{:,.0f}',
    'Numbers': '{:,.0f}',
    'Amounts': '${:,.0f}',
    'Average_Sale': '${:,.2f}',
    'Product_Conversion': '{:.2%}',
}).set_caption('Sales data <br> Produced by Team X').hide()
# Out:
# <style type="text/css">
# #T_2b3dc_row0_col0, #T_2b3dc_row0_col1, #T_2b3dc_row0_col2, #T_2b3dc_row0_col3, #T_2b3dc_row0_col4, #T_2b3dc_row0_col5, #T_2b3dc_row2_col0, #T_2b3dc_row2_col1, #T_2b3dc_row2_col2, #T_2b3dc_row2_col3, #T_2b3dc_row2_col4, #T_2b3dc_row2_col5, #T_2b3dc_row4_col0, #T_2b3dc_row4_col1, #T_2b3dc_row4_col2, #T_2b3dc_row4_col3, #T_2b3dc_row4_col4, #T_2b3dc_row4_col5 {
#   text-align: center;
#   background-color: #18314f;
# }
# #T_2b3dc_row0_col6, #T_2b3dc_row4_col6 {
#   text-align: center;
#   background-color: #18314f;
#   color: green;
# }
# #T_2b3dc_row1_col0, #T_2b3dc_row1_col1, #T_2b3dc_row1_col2, #T_2b3dc_row1_col3, #T_2b3dc_row1_col4, #T_2b3dc_row1_col5, #T_2b3dc_row3_col0, #T_2b3dc_row3_col1, #T_2b3dc_row3_col2, #T_2b3dc_row3_col3, #T_2b3dc_row3_col4, #T_2b3dc_row3_col5 {
#   text-align: center;
# }
# #T_2b3dc_row1_col6 {
#   text-align: center;
#   color: red;
# }
# #T_2b3dc_row2_col6 {
#   text-align: center;
#   background-color: #18314f;
#   color: red;
# }
# #T_2b3dc_row3_col6 {
#   text-align: center;
#   color: green;
# }
# </style>
# <table id="T_2b3dc">
#   <caption>Sales data <br> Produced by Team X</caption>
#   <thead>
#     <tr>
#       <th id="T_2b3dc_level0_col0" class="col_heading level0 col0" >Month</th>
#       <th id="T_2b3dc_level0_col1" class="col_heading level0 col1" >Quotes</th>
#       <th id="T_2b3dc_level0_col2" class="col_heading level0 col2" >Numbers</th>
#       <th id="T_2b3dc_level0_col3" class="col_heading level0 col3" >Amounts</th>
#       <th id="T_2b3dc_level0_col4" class="col_heading level0 col4" >Product</th>
#       <th id="T_2b3dc_level0_col5" class="col_heading level0 col5" >Average_Sale</th>
#       <th id="T_2b3dc_level0_col6" class="col_heading level0 col6" >Product_Conversion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b3dc_row0_col0" class="data row0 col0" >Jan-2012</td>
#       <td id="T_2b3dc_row0_col1" class="data row0 col1" >1,297,877</td>
#       <td id="T_2b3dc_row0_col2" class="data row0 col2" >427,302</td>
#       <td id="T_2b3dc_row0_col3" class="data row0 col3" >$893,590</td>
#       <td id="T_2b3dc_row0_col4" class="data row0 col4" >A</td>
#       <td id="T_2b3dc_row0_col5" class="data row0 col5" >$2.09</td>
#       <td id="T_2b3dc_row0_col6" class="data row0 col6" >32.92%</td>
#     </tr>
#     <tr>
#       <td id="T_2b3dc_row1_col0" class="data row1 col0" >Jan-2012</td>
#       <td id="T_2b3dc_row1_col1" class="data row1 col1" >557,071</td>
#       <td id="T_2b3dc_row1_col2" class="data row1 col2" >44,383</td>
#       <td id="T_2b3dc_row1_col3" class="data row1 col3" >$648,487</td>
#       <td id="T_2b3dc_row1_col4" class="data row1 col4" >B</td>
#       <td id="T_2b3dc_row1_col5" class="data row1 col5" >$14.61</td>
#       <td id="T_2b3dc_row1_col6" class="data row1 col6" >7.97%</td>
#     </tr>
#     <tr>
#       <td id="T_2b3dc_row2_col0" class="data row2 col0" >Feb-2012</td>
#       <td id="T_2b3dc_row2_col1" class="data row2 col1" >2,493,819</td>
#       <td id="T_2b3dc_row2_col2" class="data row2 col2" >358,599</td>
#       <td id="T_2b3dc_row2_col3" class="data row2 col3" >$1,089,789</td>
#       <td id="T_2b3dc_row2_col4" class="data row2 col4" >A</td>
#       <td id="T_2b3dc_row2_col5" class="data row2 col5" >$3.04</td>
#       <td id="T_2b3dc_row2_col6" class="data row2 col6" >14.38%</td>
#     </tr>
#     <tr>
#       <td id="T_2b3dc_row3_col0" class="data row3 col0" >Feb-2012</td>
#       <td id="T_2b3dc_row3_col1" class="data row3 col1" >150,071</td>
#       <td id="T_2b3dc_row3_col2" class="data row3 col2" >31,385</td>
#       <td id="T_2b3dc_row3_col3" class="data row3 col3" >$738,013</td>
#       <td id="T_2b3dc_row3_col4" class="data row3 col4" >B</td>
#       <td id="T_2b3dc_row3_col5" class="data row3 col5" >$23.51</td>
#       <td id="T_2b3dc_row3_col6" class="data row3 col6" >20.91%</td>
#     </tr>
#     <tr>
#       <td id="T_2b3dc_row4_col0" class="data row4 col0" >Mar-2012</td>
#       <td id="T_2b3dc_row4_col1" class="data row4 col1" >1,307,998</td>
#       <td id="T_2b3dc_row4_col2" class="data row4 col2" >359,458</td>
#       <td id="T_2b3dc_row4_col3" class="data row4 col3" >$807,437</td>
#       <td id="T_2b3dc_row4_col4" class="data row4 col4" >A</td>
#       <td id="T_2b3dc_row4_col5" class="data row4 col5" >$2.25</td>
#       <td id="T_2b3dc_row4_col6" class="data row4 col6" >27.48%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### **Guardar dataframe como una imagen**

# %%
df_styled = df.head().style.set_properties(**{'text-align':'center'}).apply(
    highlight_product, product='A', color='#18314f', axis=1
).apply(
    colour_threshold, subset=['Product_Conversion'], threshold= 0.2, axis=1
).format({
    # Ajustamos el formato de fecha
    'Month': '{:%b-%Y}',

    # Ajustamos el formato de los números
    'Quotes': '{:,.0f}',
    'Numbers': '{:,.0f}',
    'Amounts': '${:,.0f}',
    'Average_Sale': '${:,.2f}',
    'Product_Conversion': '{:.2%}',
}).set_caption('Sales data <br> Produced by Team X').hide()

# %%
# Definimos la ruta donde se descargar el archivo
route = '../assets/'

dfi.export(
    df_styled, 
    f'{route}/dataframe.png'
)
