# %% [markdown]
# # Matriz de Correlación

# %% [markdown]
# ### Cargamos las librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Cargamos nuestro dataset

# %%
houses = pd.read_csv('./data/Melbourne_housing.csv')

# %% [markdown]
# Creamos nuestra matriz de correlación

# %%
matrix = houses.corr()

# %% [markdown]
# Dado que nuestra matriz de correlación es simetrica podemos creamos una matriz triangular para quitar datos que pueden terminar siendo redundantes. Cambiamos a un formato booleano

# %%
mask = np.triu(np.ones_like(matrix, dtype=bool))

# %% [markdown]
# Creamos una escala de color para nuestra visualización

# %%
cmap = sns.diverging_palette(250, 15, s=75, l=40, n=9, center='light', as_cmap=True)

# %%
plt.figure(figsize=(16,12))
sns.heatmap(matrix, mask=mask, center=0, annot=True, fmt='.2f', square=True, cmap=cmap)
plt.show()
